# %% [markdown]
# <a href="https://colab.research.google.com/github/tm8600-spec/Data-science-/blob/main/Data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.array([2,4,8])*3
# Out:
# array([ 6, 12, 24])

# %%
a=np.array([1,6,8])
print(a)
# Out:
# [1 6 8]

# %%
print(a.ndim)
# Out:
# 1

# %%
b=np.array([[1,3,9,4],[7,2,5,2]])
print(b.size)
# Out:
# 8

# %%
print(b.dtype)
# Out:
# int64

# %%
print(b.shape)
# Out:
# (2, 4)

# %%
print(b.itemsize)
# Out:
# 8

# %%
c=np.array(([1,3,5,4]),dtype=np.int32)
print(c)
print(c.itemsize)
# Out:
# [1 3 5 4]
# 4

# %%
print(a[1])
# Out:
# 6

# %%
print(b.data)

# %%
d=np.array([8,9,6,7,5,3,4])
d[3]=6
print(d)
# Out:
# [8 9 6 6 5 3 4]

# %%
print(b)
# Out:
# [[1 3 9 4]
#  [7 2 5 2]]

# %%
print(b[1,1])
# Out:
# 2

# %%
a=np.ones(5)
print(a)
# Out:
# [1. 1. 1. 1. 1.]
